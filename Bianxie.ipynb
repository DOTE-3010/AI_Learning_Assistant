# %% [markdown]
# Modify the OpenAI client

# %%
from openai import OpenAI

client = OpenAI(
    api_key="sk-cJvvaaDosK2UQKWvPeyK7HyrRK004ul6L9IN7YdZm00cd7xT",
    base_url="https://api.bianxie.ai/v1"
    # Forward requests to the Bianxie AI URL
)

completion = client.chat.completions.create(
    model="gpt-3.5-turbo",
    # The only part you need to change: choose which model to route to
    messages=[
        {
            "role": "user",
            "content": "Who are you",
        }
    ]
)

print(completion.choices[0].message)

# %% [markdown]
# Modify environment variables

# %%
from openai import OpenAI
import os

os.environ["OPENAI_API_KEY"] = "sk-cJvvaaDosK2UQKWvPeyK7HyrRK004ul6L9IN7YdZm00cd7xT"

# Replace the official API endpoint with the Bianxie AI gateway endpoint
os.environ["OPENAI_BASE_URL"] = "https://api.bianxie.ai/v1"

client = OpenAI()
completion = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {
            "role": "user",
            "content": "Who are you",
        }
    ]
)

print(completion.choices[0].message)

# %% [markdown]
# Send a request directly with requests

# %%
import requests

# Replace the official API endpoint with the Bianxie AI gateway endpoint
url = 'https://api.bianxie.ai/v1/chat/completions'

headers = {

    'Content-Type': 'application/json',

    'Authorization': 'Bearer sk-cJvvaaDosK2UQKWvPeyK7HyrRK004ul6L9IN7YdZm00cd7xT' 

}

data = {

    "model": "gpt-3.5-turbo",

    "messages": [{

        "role": "user",

        "content": "Who are you"

    }],

    "stream": False

}

response = requests.post(url, json=data, headers=headers)

print(response.json())
