# %% [markdown]
# 修改OpenAI对象

# %%
from openai import OpenAI

client = OpenAI(
    api_key="sk-lXrpvF2HGabKdbMmtF9R9rcjklOqpeA2TFmmsNKWbAUE3cnW",
    base_url="https://api.bianxie.ai/v1"
    # 转发到便携AI的URL
)

completion = client.chat.completions.create(
    model="gpt-3.5-turbo",
    # 唯一需要修改的地方，指定路由到哪个模型
    messages=[
        {
            "role": "user",
            "content": "Who are you",
        }
    ]
)

print(completion.choices[0].message)

# %% [markdown]
# 修改os变量

# %%
from openai import OpenAI
import os

os.environ["OPENAI_API_KEY"] = "sk-lXrpvF2HGabKdbMmtF9R9rcjklOqpeA2TFmmsNKWbAUE3cnW"

# 这里将官方的接口访问地址替换成便携AI聚合API的入口地址
os.environ["OPENAI_BASE_URL"] = "https://api.bianxie.ai/v1"

client = OpenAI()
completion = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {
            "role": "user",
            "content": "Who are you",
        }
    ]
)

print(completion.choices[0].message)

# %% [markdown]
# 直接requests请求

# %%
import requests

# 这里将官方的接口访问地址替换成便携AI聚合API的入口地址
url = 'https://api.bianxie.ai/v1/chat/completions'

headers = {

    'Content-Type': 'application/json',

    'Authorization': 'Bearer sk-lXrpvF2HGabKdbMmtF9R9rcjklOqpeA2TFmmsNKWbAUE3cnW' 

}

data = {

    "model": "gpt-3.5-turbo",

    "messages": [{

        "role": "user",

        "content": "Who are you"

    }],

    "stream": False

}

response = requests.post(url, json=data, headers=headers)

print(response.json())
